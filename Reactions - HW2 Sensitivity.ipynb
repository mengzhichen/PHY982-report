3.21,
133.45,
115.23,
190.65]
nSa = [0.108695652,
0.217391304,
0.326086957,
0.434782609,
0.652173913,
0.869565217,
1.086956522,
1.304347826,
1.52173913,
1.630434783,
1.739130435,
1.847826087]
nSaX = [342.29,
523.83,
1107.56,
2.7,
2.7,
2.8,
2.71,
3.03,
2.78,
89.12,
77.8,
82.26]

# %% [markdown]
# # Plots

# %% [markdown]
# ### Proton / Neutron Plots

# %% [markdown]
# Proton Volume Real and Surface Imaginary Depths

# %%
plt.plot(pVV,pVVX,"-o")
plt.plot(pSW,pSWX,"-o")
plt.xlabel("Initial parameter (Relative to optimal)")
plt.ylabel(r"$\chi^2/\nu$")
plt.legend(["Real Volume Depth","Imaginary Surface Depth"])
plt.xlim((0,3))
plt.semilogy()
plt.savefig("pV.png",figsize=(4, 3), dpi=300)

# %% [markdown]
# Proton Volume Real and Surface Imaginary Radii

# %%
plt.plot(pVr,pVrX,"-o")
plt.plot(pSr,pSrX,"-o")
plt.xlabel("Initial parameter (Relative to optimal)")
plt.ylabel(r"$\chi^2/\nu$")
plt.legend(["Real Volume radius","Imaginary Surface radius"])
plt.semilogy()
plt.savefig("pr.png",figsize=(4, 3), dpi=300)

# %% [markdown]
# Proton Volume Real and Surface Imaginary Diffuseness

# %%
plt.plot(pVa,pVaX,"-o")
plt.plot(pSa,pSaX,"-o")
plt.xlabel("Initial parameter (Relative to optimal)")
plt.ylabel(r"$\chi^2/\nu$")
plt.legend(["Real Volume Diffuseness","Imaginary Surface Diffuseness"])
plt.semilogy()
plt.savefig("pa.png",figsize=(4, 3), dpi=300)

# %% [markdown]
# Neutron Volume Real and Surface Imaginary Depth

# %%
plt.plot(nVV,nVVX,"-o")
plt.plot(nSW,nSWX,"-o")
plt.xlabel("Initial parameter (Relative to optimal)")
plt.ylabel(r"$\chi^2/\nu$")
plt.legend(["Real Volume Depth","Imaginary Surface Depth"])
plt.semilogy()
plt.savefig("nV.png",figsize=(4, 3), dpi=300)

# %% [markdown]
# Neutron Volume Real and Surface Imaginary Radii

# %%
plt.plot(nVr,nVrX,"-o")
plt.plot(nSr,nSrX,"-o")
plt.xlabel("Initial parameter (Relative to optimal)")
plt.ylabel(r"$\chi^2/\nu$")
plt.legend(["Real Volume radius","Imaginary Surface radius"])
plt.semilogy()
plt.savefig("nr.png",figsize=(4, 3), dpi=300)

# %% [markdown]
# Neutron Volume Real and Surface Imaginary Diffuseness

# %%
plt.plot(nVa,nVaX,"-o")
plt.plot(nSa,nSaX,"-o")
plt.xlabel("Initial parameter (Relative to optimal)")
plt.ylabel(r"$\chi^2/\nu$")
plt.legend(["Real Volume Diffuseness","Imaginary Surface Diffuseness"])
plt.semilogy()
plt.savefig("na.png",figsize=(4, 3), dpi=300)

# %% [markdown]
# ### Proton and Neutron Plots

# %%
plt.plot(pVV,pVVX,"-o")
plt.plot(pSW,pSWX,"-o")
plt.plot(nVV,nVVX,"-o")
plt.plot(nSW,nSWX,"-o")
plt.xlabel("Initial Depth (Relative to optimal)")
plt.ylabel(r"$\chi^2/\nu$")
plt.legend([r"$\pi$ Volume $V_0$",r"$\pi$ Surface $W_0$",r"$\nu$ Volume $V_0$",r"$\nu$ Surface $W_0$"])
plt.xlim((0,3))
plt.semilogy()
plt.savefig("pnV.png",figsize=(4, 3), dpi=300)

# %%
plt.plot(pVr,pVrX,"-o")
plt.plot(pSr,pSrX,"-o")
plt.plot(nVr,nVrX,"-o")
plt.plot(nSr,nSrX,"-o")
plt.xlabel("Initial Nuclear Radius (Relative to optimal)")
plt.ylabel(r"$\chi^2/\nu$")
plt.legend([r"$\pi$ Volume $r_0$",r"$\pi$ Surface $r_{s0}$",r"$\nu$ Volume $r_0$",r"$\nu$ Surface $r_{s0}$"])
plt.semilogy()
plt.savefig("pnr.png",figsize=(4, 3), dpi=300)

# %%
plt.plot(pVa,pVaX,"-o")
plt.plot(pSa,pSaX,"-o")
plt.plot(nVa,nVaX,"-o")
plt.plot(nSa,nSaX,"-o")
plt.xlabel("Initial Diffuseness (Relative to optimal)")
plt.ylabel(r"$\chi^2/\nu$")
plt.legend([r"$\pi$ Volume $a_0$",r"$\pi$ Surface $a_{s0}$",r"$\nu$ Volume $a_0$",r"$\nu$ Surface $a_{s0}$"])
plt.semilogy()
plt.savefig("pna.png",figsize=(4, 3), dpi=300)
